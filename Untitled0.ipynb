# %%
print("hi my name is veer")
print("i like to play football")
print("im really goood at playing foootball")
print("the result of 2x5=",2*5)
# Out:
# hi my name is veer
# i like to play football
# im really goood at playing foootball
# the result of 2x5= 10
