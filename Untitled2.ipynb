# %% [markdown]
# <a href="https://colab.research.google.com/github/veerallagh123-lab/python-class-/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a=5
print(type(a))
b=1.5
print(type(b))
c="veer"
print(type(c))
d=False
print(type(d))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>

# %%
name="veer"
age=16
is_student=True
weight=67.8
print(name)
print(age)
print(is_student)
print(weight)
print(type(name))
print(type(age))
print(type(is_student))
print(type(weight))
print("typecasting will happen next")
age=str(age)
print(type(age))
weight=int(weight)
print(type(weight))
# Out:
# veer
# 16
# True
# 67.8
# <class 'str'>
# <class 'int'>
# <class 'bool'>
# <class 'float'>
# typecasting will happen next
# <class 'str'>
# <class 'int'>
